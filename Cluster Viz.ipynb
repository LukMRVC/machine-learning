# %%
import pandas as pd # dataframes
import numpy as np # matrices and linear algebra
import matplotlib.pyplot as plt # plotting
import seaborn as sns # another matplotlib interface - styled and easier to use

# %%
df = pd.read_csv('./clustering/boxes-singl-euclid-clusters-5.csv', sep=';')
df.head()
# Out:
#            x          y cluster
# 0 -22.365952 -48.805958      C1
# 1 -24.687658 -45.904180      C1
# 2 -24.813440 -45.835310      C1
# 3 -25.318750 -46.162300      C1
# 4 -25.074818 -46.555690      C1

# %%
sns.scatterplot(data=df, x='x', y='y', hue='cluster')
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 20))

for idx, clusters in enumerate([5, 3, 2]):
    df = pd.read_csv(f'./clustering/boxes-singl-manhat-clusters-{clusters}.csv', sep=';')
    sns.scatterplot(data=df, x='x', y='y', hue='cluster', ax=axes[idx])

# %%
fig, axes = plt.subplots(3, 1, figsize=(10, 20))

for idx, clusters in enumerate([5, 3, 2]):
    title = f'clusters5n-comp-euclid-clusters-{clusters}'
    df = pd.read_csv(f'./clustering/{title}.csv', sep=';')
    axx = sns.scatterplot(data=df, x='x', y='y', hue='cluster', ax=axes[idx])
    axx.set(title=title)
    # plt.title(title)
